# %% [markdown]
# ## Matplotlib
#
# **Matplotlib** is a comprehensive library for creating static, animated, and interactive visualizations in Python. Below, we'll explore its features step-by-step.

# %%
import pandas as pd
df = pd.read_csv('canadian_immegration_data.csv', index_col=0)

# %%
df.head()
# Out:
#                Continent           Region             DevName  1980  1981  \
# Country
# Afghanistan         Asia    Southern Asia  Developing regions    16    39
# Albania           Europe  Southern Europe   Developed regions     1     0
# Algeria           Africa  Northern Africa  Developing regions    80    67
# American Samoa   Oceania        Polynesia  Developing regions     0     1
# Andorra           Europe  Southern Europe   Developed regions     0     0
#
#                 1982  1983  1984  1985  1986  ...  2005  2006  2007  2008  \
# Country                                       ...
# Afghanistan       39    47    71   340   496  ...  3436  3009  2652  2111
# Albania            0     0     0     0     1  ...  1223   856   702   560
# Algeria           71    69    63    44    69  ...  3626  4807  3623  4005
# American Samoa     0     0     0     0     0  ...     0     1     0     0
# Andorra            0     0     0     0     2  ...     0     1     1     0
#
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 195 entries, Afghanistan to Zimbabwe
# Data columns (total 38 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   Continent  195 non-null    object
#  1   Region     195 non-null    object
#  2   DevName    195 non-null    object
#  3   1980       195 non-null    int64
#  4   1981       195 non-null    int64
#  5   1982       195 non-null    int64
#  6   1983       195 non-null    int64
#  7   1984       195 non-null    int64
#  8   1985       195 non-null    int64
#  9   1986       195 non-null    int64
#  10  1987       195 non-null    int64
#  11  1988       195 non-null    int64
#  12  1989       195 non-null    int64
#  13  1990       195 non-null    int64
#  14  1991       195 non-null    int64
#  15  1992       195 non-null    int64
#  16  1993       195 non-null    int64
#  17  1994       195 non-null    int64
#  18  1995       195 non-null    int64
# ...

# %%
df.describe()
# Out:
#                1980          1981          1982          1983          1984  \
# count    195.000000    195.000000    195.000000    195.000000    195.000000
# mean     508.394872    566.989744    534.723077    387.435897    376.497436
# std     1949.588546   2152.643752   1866.997511   1204.333597   1198.246371
# min        0.000000      0.000000      0.000000      0.000000      0.000000
# 25%        0.000000      0.000000      0.000000      0.000000      0.000000
# 50%       13.000000     10.000000     11.000000     12.000000     13.000000
# 75%      251.500000    295.500000    275.000000    173.000000    181.000000
# max    22045.000000  24796.000000  20620.000000  10015.000000  10170.000000
#
#               1985         1986          1987          1988          1989  \
# count   195.000000   195.000000    195.000000    195.000000    195.000000
# mean    358.861538   441.271795    691.133333    714.389744    843.241026
# ...

# %%
df.describe(include='object')
# Out:
#        Continent        Region             DevName
# count        195           195                 195
# unique         6            22                   2
# top       Africa  Western Asia  Developing regions
# freq          54            18                 147

# %% [markdown]
# ### Installation
# If you don't have Matplotlib installed, you can use the following command:
# ```bash
# !pip install matplotlib
# ```

# %%
# Installing matplotlib
#!pip install matplotlib

# %%
# Import Matplotlib and check the version installed to ensure it's set up correctly.
import matplotlib

# Prints the version of Matplotlib installed.
print(matplotlib.__version__)
# Out:
# 3.10.0

# %% [markdown]
# ### Pyplot
#
# The `pyplot` module in Matplotlib provides a simple interface for creating plots and visualizations. Let's import it.

# %%
# Import the pyplot module and alias it as plt.
import matplotlib.pyplot as plt

years=list(map(str,range(1980,2014)))
df.loc["Afghanistan",years].plot(kind='line')
df.loc['Egypt',years].plot(kind='line')
plt.ylabel('Number of Immigrants')
plt.xlabel('Years')
plt.title('Afghanistan vs Egypt Immigrants')
plt.legend(['Afghanistan','Egypt'])
plt.show()

# %% [markdown]
# ### Example: Drawing a Line
# Use `plt.plot()` to draw a line between two points.

# %%
# Draw a line in a diagram from position (0,0) to position (6,250):

# Import NumPy for numerical operations.
import numpy as np

# Define x-coordinates of the line.
xpoints = np.array([0, 6])
# Define y-coordinates of the line.
ypoints = np.array([0, 250])

# Plot the line using xpoints and ypoints.
plt.plot(xpoints, ypoints)  
# Display the plot.
plt.show()

# %% [markdown]
# ### Plotting Without a Line
#
# You can visualize points without connecting them using a line.

# %%
# Plotting Without Line
# Define x-coordinates for points.
xpoints = np.array([1, 8])
# Define y-coordinates for points.
ypoints = np.array([3, 10])

# Use 'o' to plot only the points.
plt.plot(xpoints, ypoints, 'o')
# Display the plot.
plt.show()

# %% [markdown]
# ### Multiple Points
#
# Plot multiple points and connect them with a line.

# %%
# Multiple Points
# You can plot as many points as you like, just make sure you have the same number of points in both axis.

# Define x-coordinates for multiple points.
xpoints = np.array([1, 2, 6, 8])

# Define corresponding y-coordinates.
ypoints = np.array([3, 8, 1, 10])

# Plot the points and connect them with a line.
plt.plot(xpoints, ypoints)

# Display the plot.
plt.show()

# %% [markdown]
# ### Default X-Points
#
# If we do not specify the points in the x-axis, they will get the default values 0, 1, 2, 3, (etc. depending on the length of the y-points.

# %%
# Define y-coordinates for the points.
ypoints = np.array([3, 8, 1, 10, 5, 7])

# Plot the points with default x-coordinates.
plt.plot(ypoints)   #default: 0 1 2 3 4 5

# Display the plot.
plt.show()

# %% [markdown]
# ## Markers
# Markers are used to emphasize points in a plot.

# %%
# You can use the keyword argument marker to emphasize each point with a specified marker:

# Define y-coordinates.
ypoints = np.array([3, 8, 1, 10])

# Add circle markers to each point.
plt.plot(ypoints, marker = 'o')

# Display the plot.
plt.show()

# %%
# Use a star as a marker.
plt.plot(ypoints, marker = '*')

# %% [markdown]
# ### Formatting Markers and Lines
#
# Customize markers, lines, and colors using the `fmt` parameter.

# %%
# Format Strings fmt
# This parameter is also called fmt, and is written with this syntax:
# marker|line|color
ypoints = np.array([3, 8, 1, 10])

# Circle markers, dashed line, and red color.
plt.plot(ypoints, 'o:r')

# Display the plot.
plt.show()

# %% [markdown]
# ### Marker Size
#
# Adjust the size of the markers using the `ms` (marker size) parameter.

# %%
# Set marker size to 20: marker size is set using the keyword argument ms.
plt.plot(ypoints, marker = 'o', ms = 20)

# Display the plot.
plt.show()

# %% [markdown]
# ### Marker Color
#
# Customize marker edge color using `mec` and face color using `mfc`.

# %%
#Marker Color
# Red edge.
# marker edge color is set using the keyword argument mec.
plt.plot(ypoints, marker = 'o', mec = 'r')

# Display the plot.
plt.show()

# %%
# You can use the keyword argument markerfacecolor or the shorter mfc 
# to set the color inside the edge of the markers:
# Red face.
plt.plot(ypoints, marker = 'o', mfc = 'r')

# Display the plot.
plt.show()

# %%
# Set the color of both the edge and the face to red:
# Red edge and face.
plt.plot(ypoints, marker = 'o', mec = 'r', mfc = 'r')

# Display the plot.
plt.show()

# %% [markdown]
# ## Line Properties
#
# Adjust the thickness of the line using `linewidth`.

# %%
# Set line width to 2.5.
plt.plot(ypoints, linewidth = 2.5)

# Display the plot.
plt.show()

# %% [markdown]
# ## Multiple Lines
#
# You can plot multiple lines in a single chart.

# %%
# Multiple Lines

# First line data.
y1 = np.array([3, 8, 1, 10])

# Second line data.
y2 = np.array([6, 2, 7, 11])

# Plot the first line.
plt.plot(y1)

# Plot the second line.
plt.plot(y2)

# Display the plot.
plt.show()

# %%
# Alternatively, you can explicitly define both `x` and `y` for each line.

# x-coordinates for the first line.
x1 = np.array([0, 1, 2, 3])

# y-coordinates for the first line.
y1 = np.array([3, 8, 1, 10])

# x-coordinates for the second line.
x2 = np.array([0, 1, 2, 3])

# y-coordinates for the second line.
y2 = np.array([6, 2, 7, 11])

# Plot both lines on the same chart.
plt.plot(x1, y1, x2, y2)

# Display the plot.
plt.show()

# %% [markdown]
# ## Adding Labels and Titles
#
# Label the x and y axes and add a title to make the chart more descriptive.

# %%
# x-axis data.
x = np.array([80, 85, 90, 95, 100, 105, 110, 115, 120, 125])

# y-axis data.
y = np.array([240, 250, 260, 270, 280, 290, 300, 310, 320, 330])

# Plot the data.
plt.plot(x, y)

# Label the x-axis.
plt.xlabel('x-axis')

# Label the y-axis.
plt.ylabel('y-axis')

# Display the plot.
plt.show()

# %% [markdown]
# ## Adding Titles and Labels to Plots
#
# Titles and labels help make your plots more descriptive and informative.

# %%
# Create a title and add labels to the axes.

# X-axis data points.
x = np.array([80, 85, 90, 95, 100, 105, 110, 115, 120, 125])

# Y-axis data points.
y = np.array([240, 250, 260, 270, 280, 290, 300, 310, 320, 330])

# Plot the line using x and y data points.
plt.plot(x, y)

# Add a title to the plot.
plt.title('Title of the Plot')

# Label the x-axis.
plt.xlabel('x-axis')

# Label the y-axis.
plt.ylabel('y_axis')

# Display the plot.
plt.show()

# %%
# Set font properties for the title and labels:

# X-axis data points.
x = np.array([80, 85, 90, 95, 100, 105, 110, 115, 120, 125])

# Y-axis data points.
y = np.array([240, 250, 260, 270, 280, 290, 300, 310, 320, 330])

# Set font properties for the title and labels.

# Define font properties for the title.
font1={'family':'serif','color':'purple','size':20}

# Define font properties for labels.
font2={'family':'serif','color':'gray','size':20}


# Apply font1 to the title.
plt.title('Title of the Plot', fontdict = font1)

# Apply font2 to the x-axis label.
plt.xlabel('x-axis', fontdict = font2)

# Apply font2 to the y-axis label.
plt.ylabel('y_axis', fontdict = font2)

# Plot the line using x and y data points.
plt.plot(x, y)

# Display the plot.
plt.show()

# %%
# Position the title at the left of the plot.

# X-axis data points.
x = np.array([80, 85, 90, 95, 100, 105, 110, 115, 120, 125])

# Y-axis data points.
y = np.array([240, 250, 260, 270, 280, 290, 300, 310, 320, 330])

# Position the title at the left of the plot.
plt.title('Title of the Plot', loc = 'left')

# Add x-axis label.
plt.xlabel('x-axis')

# Add y-axis label.
plt.ylabel('y_axis')

# Plot the line.
plt.plot(x, y)

# Display the plot.
plt.show()

# %% [markdown]
# ## Adding Grid Lines
#
# Grid lines help to make the plot easier to read by highlighting the graph's scale.

# %%
# Add grid lines to the plot.

# X-axis data points.
x = np.array([80, 85, 90, 95, 100, 105, 110, 115, 120, 125])

# Y-axis data points.
y = np.array([240, 250, 260, 270, 280, 290, 300, 310, 320, 330])

# Add a title.
plt.title('Title of the Plot')

# Label the x-axis.
plt.xlabel('x-axis')

# Label the y-axis.
plt.ylabel('y_axis')

# Plot the data points.
plt.plot(x, y)

# Add grid lines.
plt.grid()

# Display the plot.
plt.show()

# %% [markdown]
# ## Subplots
#
# Subplots allow you to create multiple plots in one figure.

# %%
# Create two subplots in one row.
# Plot 1:
# X-axis data for the first plot.
x = np.array([0, 1, 2, 3])

# Y-axis data for the first plot.
y = np.array([3, 8, 1, 10])

# Create a subplot (1 row, 2 columns, this is the 1st plot).
plt.subplot(1, 2, 1)

# Plot the data.
plt.plot(x, y)

# Plot 2:
# X-axis data for the first plot.
x = np.array([0, 1, 2, 3])

# Y-axis data for the second plot.
y = np.array([10, 20, 30, 40])

# Create a subplot (1 row, 2 columns, this is the 2nd plot).
plt.subplot(1, 2, 2)

# Plot the data.
plt.plot(x, y)

# Display the subplots.
plt.show()

# %%
# Create two subplots in one row with titles.
# Plot 1:
# X-axis data for the first plot.
x = np.array([0, 1, 2, 3])

# Y-axis data for the first plot.
y = np.array([3, 8, 1, 10])

# Create a subplot (1 row, 2 columns, this is the 1st plot).


# Plot the data.


# Add a title to the first plot.


# Plot 2:
# X-axis data for the first plot.
x = np.array([0, 1, 2, 3])

# Y-axis data for the second plot.
y = np.array([10, 20, 30, 40])

# Create a subplot (1 row, 2 columns, this is the 2nd plot).


# Plot the data.


# Add a title to the second plot.


# Display the subplots.
plt.show()

# %%
# Add a super title for the entire figure.
# Plot 1:
# X-axis data for the first plot.
x = np.array([0, 1, 2, 3])

# Y-axis data for the first plot.
y = np.array([3, 8, 1, 10])

# Create a subplot (1 row, 2 columns, this is the 1st plot).
plt.subplot(1, 2, 1)

# Plot the data.
plt.plot(x, y)

# Add a title to the first plot.
plt.title('First Plot') 

# Plot 2:
# X-axis data for the first plot.
x = np.array([0, 1, 2, 3])

# Y-axis data for the second plot.
y = np.array([10, 20, 30, 40])

# Create a subplot (1 row, 2 columns, this is the 2nd plot).
plt.subplot(1,2,2)

# Plot the data.
plt.plot(x, y)

# Add a title to the second plot.
plt.title('Second Plot')

# Add a super title for the entire figure.
plt.suptitle('My Subplots')

# Display the subplots.
plt.show()

# %% [markdown]
# ## Scatter Plots
#
# Scatter plots show the relationship between two sets of data points.

# %%
# Create a scatter plot.
# X-axis data points.
x = np.array([5,7,8,7,2,17,2,9,4,11,12,9,6])

# Y-axis data points.
y = np.array([99,86,87,88,111,86,103,87,94,78,77,85,86])

# Create the scatter plot.
plt.scatter(x, y)

# Display the plot.
plt.show()

# %%
# Draw two scatter plots on the same figure.
# X-axis data points.
x = np.array([5,7,8,7,2,17,2,9,4,11,12,9,6])

# Y-axis data points.
y = np.array([99,86,87,88,111,86,103,87,94,78,77,85,86])

# Create the scatter plot.
plt.scatter(x, y)

# X-axis data points.
x = np.array([2,2,8,1,15,8,12,9,7,3,11,4,7,14,12])

# Y-axis data points.
y = np.array([100,105,84,105,90,99,90,95,94,100,79,112,91,80,85])

# Create the scatter plot.
plt.scatter(x, y)

# Display the plot.
plt.show()

# %%
# Draw two scatter plots on the same figure with different colors:
# X-axis data points.
x = np.array([5,7,8,7,2,17,2,9,4,11,12,9,6])

# Y-axis data points.
y = np.array([99,86,87,88,111,86,103,87,94,78,77,85,86])

# Scatter plot for the first dataset with the color hotpink.
plt.scatter(x, y, color = 'hotpink')

# X-axis data points.
x = np.array([2,2,8,1,15,8,12,9,7,3,11,4,7,14,12])

# Y-axis data points.
y = np.array([100,105,84,105,90,99,90,95,94,100,79,112,91,80,85])

# Scatter plot for the second dataset with the color code #88c999.
plt.scatter(x, y, color = '#88c999')

# Display the plot.
plt.show()

# %%
# Adding a color map to scatter plots
# X-axis data points.
x = np.array([5,7,8,7,2,17,2,9,4,11,12,9,6])

# Y-axis data points.
y = np.array([99,86,87,88,111,86,103,87,94,78,77,85,86])

# Assign a color value for each point.
colors=np.array([0, 10, 20, 30, 40, 45, 50, 55, 60, 70, 80, 90, 100])

# Use the "viridis" colormap for the points.
plt.scatter(x, y, c = colors, cmap = 'viridis')

# Add a color scale bar for reference.
plt.colorbar()

# Display the plot.
plt.show()

# %%
# Adding a color map to scatter plots
# X-axis data points.
x = np.array([5,7,8,7,2,17,2,9,4,11,12,9,6])

# Y-axis data points.
y = np.array([99,86,87,88,111,86,103,87,94,78,77,85,86])

# Assign a color value for each point.
plt.scatter(x, y, c = y)

# Use the "viridis" colormap for the points.
plt.colormap = 'viridis'

# Add a color scale bar for reference.
plt.colorbar()

# Display the plot.
plt.show()

# %%
# Set custom marker sizes for the scatter plot

x = np.array([5,7,8,7,2,17,2,9,4,11,12,9,6])

# Y-axis data points.
y = np.array([99,86,87,88,111,86,103,87,94,78,77,85,86])

# Assign marker sizes.
sizes=np.array([20,50,100,200,500,1000,60,90,10,300,600,800,75])

# Use the "s" argument to set marker sizes.
plt.scatter(x, y, s = sizes)

# Display the plot.
plt.show()

# %%
# Set custom marker sizes for the scatter plot

x = np.array([5,7,8,7,2,17,2,9,4,11,12,9,6])

# Y-axis data points.
y = np.array([99,86,87,88,111,86,103,87,94,78,77,85,86])

# Assign marker sizes.
# Use the "s" argument to set marker sizes.
plt.scatter(x, y, s = 100)

# Display the plot.
plt.show()

# %% [markdown]
# ## Bars
#
# Visualize categorical data with bar charts.

# %%
# Categories on the x-axis.
x = np.array(["A", "B", "C", "D"])

# Values for each category.
y = np.array([3, 8, 1, 10])

# Create the bar chart.
plt.bar(x, y)

# Display the chart.
plt.show()

# %%
# Customize the color of the bars.
# Set the bar color to red.
plt.bar(x, y, color = 'red')

# Display the chart.
plt.show()

# %%
# Adjust the width of the bars.
# Categories on the x-axis.
x = np.array(["A", "B", "C", "D"])

# Values for each category.
y = np.array([3, 8, 1, 10])

# Reduce the width of the bars.
plt.bar(x, y, color='green', width = 0.2)

# Display the chart.
plt.show()

# %% [markdown]
# ## Histogram
#
# A histogram is a graph showing frequency distributions.
#
# It is a graph showing the number of observations within each given interval.

# %% [markdown]
# Shows the data distribution

# %%
# Generate a dataset with a normal distribution.
x = np.random.normal(170, 10, 250)

# Print the generated data points.
print(x)
# Out:
# [143.6385493  161.34934371 155.63339766 160.15827947 160.71999289
#  172.45871482 179.8412869  196.44082759 181.41253777 163.27158225
#  158.16341089 153.7417836  183.75332654 165.837171   168.81359373
#  171.64203707 166.18433651 167.96299643 176.73537364 158.84591482
#  162.01599063 185.51711081 178.37978782 155.49372108 148.86811496
#  152.19195386 169.9254401  173.99443823 185.77052755 148.44208499
#  187.1691593  168.64473391 178.0152881  168.78352892 148.57914455
#  160.28394834 169.58392659 168.42239722 186.76405809 165.12757079
#  169.36371313 171.43376149 174.2732587  160.15534272 155.77005809
#  173.17113462 171.00732439 169.07413592 172.31973342 164.75488162
#  179.68719944 176.84560217 176.09044274 164.57075642 187.97946983
#  166.89591457 159.6344096  170.76244046 168.29053038 180.74974142
#  178.37770611 195.2103023  184.32812122 169.25343472 162.34325846
#  175.27650905 167.97377543 168.07597102 194.67450102 173.62537623
# ...

# %%
# Create a histogram to visualize the distribution of the data.
# Plot the histogram.
#no need for 'y' it is the freq it calculates automatically -->used in univariate analysis
plt.hist(x)

# Display the plot.
plt.show()

# %% [markdown]
# Example: Say you ask for the height of 250 people, you might end up with a histogram like this:
#
# * 2 people from 140 to 145cm
# * 5 people from 145 to 150cm
# * 15 people from 151 to 156cm
# * 31 people from 157 to 162cm

# %% [markdown]
# ## Pie Charts
#
# Pie charts represent parts of a whole.

# %%
# Create a simple pie chart.

# Values for each pie slice.
y = np.array([35, 25, 25, 15])

# Create the pie chart.
plt.pie(y)

# Display the chart.
plt.show()

# %%
# Add labels to the pie chart.
# Values for each slice.
y = np.array([35, 25, 25, 15])

# Labels for each slice.
mylabels = ["Apples", "Bananas", "Cherries", "Dates"]

# Create the pie chart with labels.
plt.pie(y, labels = mylabels)

# Display the chart.
plt.show()

# %%
# Add labels to the pie chart with explode property
# Values for each slice.
y = np.array([35, 25, 25, 15])

# Labels for each slice.
mylabels = ["Apples", "Bananas", "Cherries", "Dates"]
exp_list = [0.2, 0.1, 0.1, 0.1]
# Create the pie chart with labels.
plt.pie(y, labels = mylabels, explode=exp_list, shadow=True)

# Display the chart.
plt.show()
