# %% [markdown]
# # Exploratory Data Analysis with SQL
#
# The purpose here is to use some queries to explore the data.

# %%
# !pip install seaborn
# Out:
# Collecting seaborn
#   Downloading seaborn-0.13.2-py3-none-any.whl.metadata (5.4 kB)
# Requirement already satisfied: numpy!=1.24.0,>=1.20 in c:\users\aya\documents\new folder\envs\depi_env\lib\site-packages (from seaborn) (2.2.1)
# Requirement already satisfied: pandas>=1.2 in c:\users\aya\documents\new folder\envs\depi_env\lib\site-packages (from seaborn) (2.2.3)
# Requirement already satisfied: matplotlib!=3.6.1,>=3.4 in c:\users\aya\documents\new folder\envs\depi_env\lib\site-packages (from seaborn) (3.10.0)
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\aya\documents\new folder\envs\depi_env\lib\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (1.3.1)
# Requirement already satisfied: cycler>=0.10 in c:\users\aya\documents\new folder\envs\depi_env\lib\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\aya\documents\new folder\envs\depi_env\lib\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (4.55.3)
# Requirement already satisfied: kiwisolver>=1.3.1 in c:\users\aya\documents\new folder\envs\depi_env\lib\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (1.4.8)
# Requirement already satisfied: packaging>=20.0 in c:\users\aya\documents\new folder\envs\depi_env\lib\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (24.2)
# Requirement already satisfied: pillow>=8 in c:\users\aya\documents\new folder\envs\depi_env\lib\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (11.1.0)
# Requirement already satisfied: pyparsing>=2.3.1 in c:\users\aya\documents\new folder\envs\depi_env\lib\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (3.2.1)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\aya\documents\new folder\envs\depi_env\lib\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (2.9.0)
# Requirement already satisfied: pytz>=2020.1 in c:\users\aya\documents\new folder\envs\depi_env\lib\site-packages (from pandas>=1.2->seaborn) (2024.2)
# Requirement already satisfied: tzdata>=2022.7 in c:\users\aya\documents\new folder\envs\depi_env\lib\site-packages (from pandas>=1.2->seaborn) (2024.2)
# Requirement already satisfied: six>=1.5 in c:\users\aya\documents\new folder\envs\depi_env\lib\site-packages (from python-dateutil>=2.7->matplotlib!=3.6.1,>=3.4->seaborn) (1.16.0)
# Downloading seaborn-0.13.2-py3-none-any.whl (294 kB)
# Installing collected packages: seaborn
# Successfully installed seaborn-0.13.2

# %%
# Sqlite is a library that implements a SQL database engine. 
import sqlite3
import numpy as np
import pandas as pd
# %matplotlib inline
import matplotlib.pyplot as plt
import seaborn as sns

# %%
#connection
conn=sqlite3.connect('database.sqlite')
cursor = conn.cursor()
print("Database connection established successfully.")
# Out:
# Database connection established successfully.

# %%
#sqlite_master is a table with database schema
schema=pd.read_sql(""" SELECT *
                FROM sqlite_master
                WHERE type='table';""",
           conn)

schema
# Out:
#     type          name      tbl_name  rootpage  \
# 0  table       Country       Country         2
# 1  table  CountryNotes  CountryNotes       186
# 2  table        Series        Series       948
# 3  table    Indicators    Indicators      4448
# 4  table   SeriesNotes   SeriesNotes   1317550
# 5  table     Footnotes     Footnotes   1317587
#
#                                                  sql
# 0  CREATE TABLE Country (\n    CountryCode TEXT,\...
# 1  CREATE TABLE CountryNotes (\n    Countrycode T...
# 2  CREATE TABLE Series (\n    SeriesCode TEXT,\n ...
# 3  CREATE TABLE Indicators (\n    CountryName TEX...
# 4  CREATE TABLE SeriesNotes (\n    Seriescode TEX...
# 5  CREATE TABLE Footnotes (\n    Countrycode TEXT...

# %% [markdown]
# ## <span style='color:DarkGoldenrod'> Let's explore the Indicators table.  </span>

# %% [markdown]
# # 1- Selecting

# %%
# check the head
indic=pd.read_sql("""SELECT *
               FROM Indicators;""",
           conn)

indic.head()
# Out:
#   CountryName CountryCode                                      IndicatorName  \
# 0  Arab World         ARB  Adolescent fertility rate (births per 1,000 wo...
# 1  Arab World         ARB  Age dependency ratio (% of working-age populat...
# 2  Arab World         ARB  Age dependency ratio, old (% of working-age po...
# 3  Arab World         ARB  Age dependency ratio, young (% of working-age ...
# 4  Arab World         ARB        Arms exports (SIPRI trend indicator values)
#
#     IndicatorCode  Year         Value
# 0     SP.ADO.TFRT  1960  1.335609e+02
# 1     SP.POP.DPND  1960  8.779760e+01
# 2  SP.POP.DPND.OL  1960  6.634579e+00
# 3  SP.POP.DPND.YG  1960  8.102333e+01
# 4  MS.MIL.XPRT.KD  1960  3.000000e+06

# %%
# how many rows?
indic.shape # 5656458 rows, 6 columns
# Out:
# (5656458, 6)

# %%
# checking for missing values in one column ('IndicatorName')
print(indic['IndicatorName'].isnull().sum())

# check datatypes (for all columns)
indic.info()
# Out:
# 0
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5656458 entries, 0 to 5656457
# Data columns (total 6 columns):
#  #   Column         Dtype
# ---  ------         -----
#  0   CountryName    object
#  1   CountryCode    object
#  2   IndicatorName  object
#  3   IndicatorCode  object
#  4   Year           int64
#  5   Value          float64
# dtypes: float64(1), int64(1), object(4)
# memory usage: 258.9+ MB

# %%
# if I need filter not null
filter=pd.read_sql("""SELECT *
               FROM Indicators
               WHERE IndicatorName IS NOT NULL;""",
           conn)

filter.head()
# Out:
#   CountryName CountryCode                                      IndicatorName  \
# 0  Arab World         ARB  Adolescent fertility rate (births per 1,000 wo...
# 1  Arab World         ARB  Age dependency ratio (% of working-age populat...
# 2  Arab World         ARB  Age dependency ratio, old (% of working-age po...
# 3  Arab World         ARB  Age dependency ratio, young (% of working-age ...
# 4  Arab World         ARB        Arms exports (SIPRI trend indicator values)
#
#     IndicatorCode  Year         Value
# 0     SP.ADO.TFRT  1960  1.335609e+02
# 1     SP.POP.DPND  1960  8.779760e+01
# 2  SP.POP.DPND.OL  1960  6.634579e+00
# 3  SP.POP.DPND.YG  1960  8.102333e+01
# 4  MS.MIL.XPRT.KD  1960  3.000000e+06

# %%
# checking for missing values in all columns
indic.isnull().sum()
# Out:
# CountryName      0
# CountryCode      0
# IndicatorName    0
# IndicatorCode    0
# Year             0
# Value            0
# dtype: int64

# %%
# how many indicators?
indicCount=pd.read_sql("""SELECT COUNT (DISTINCT IndicatorName)
                FROM Indicators;""",
           conn)

indicCount
# Out:
#    COUNT (DISTINCT IndicatorName)
# 0                            1344

# %%
# selecting distinct indicators
distinctIndic=pd.read_sql("""SELECT DISTINCT IndicatorName
                FROM Indicators;""",
           conn)

distinctIndic.head()
# Out:
#                                        IndicatorName
# 0  2005 PPP conversion factor, GDP (LCU per inter...
# 1  2005 PPP conversion factor, private consumptio...
# 2  ARI treatment (% of children under 5 taken to ...
# 3            Access to electricity (% of population)
# 4  Access to electricity, rural (% of rural popul...

# %% [markdown]
# # 2- Filtering

# %%
# I wanna search for some indicator about GDP
GDPiNDIC=pd.read_sql("""SELECT DISTINCT IndicatorName
               FROM Indicators
               WHERE IndicatorName LIKE 'GDP%';""",
           conn)

GDPiNDIC.head()
# Out:
#                                 IndicatorName
# 0                          GDP (constant LCU)
# 1                           GDP (current LCU)
# 2    GDP at market prices (constant 2005 US$)
# 3          GDP at market prices (current US$)
# 4  GDP deflator (base year varies by country)

# %%
# how about GDP per capita of Brazil in last years ?
BrazilGPD=pd.read_sql(""" SELECT *
                FROM Indicators
                WHERE IndicatorName ='GDP per capita (current US$)'
                AND CountryName = "Brazil"
                AND Year>=2012;""",
           conn)

BrazilGPD.head()
# Out:
#   CountryName CountryCode                 IndicatorName   IndicatorCode  Year  \
# 0      Brazil         BRA  GDP per capita (current US$)  NY.GDP.PCAP.CD  2012
# 1      Brazil         BRA  GDP per capita (current US$)  NY.GDP.PCAP.CD  2013
# 2      Brazil         BRA  GDP per capita (current US$)  NY.GDP.PCAP.CD  2014
#
#           Value
# 0  11922.513058
# 1  11711.004405
# 2  11384.415010

# %%
# let's  compare with China
ChinaGPD=pd.read_sql(""" SELECT *
                FROM Indicators
                WHERE IndicatorName ='GDP per capita (current US$)'
                AND CountryName = "China"
                AND Year>=2012;""",
           conn)

ChinaGPD.head()
# Out:
#   CountryName CountryCode                 IndicatorName   IndicatorCode  Year  \
# 0       China         CHN  GDP per capita (current US$)  NY.GDP.PCAP.CD  2012
# 1       China         CHN  GDP per capita (current US$)  NY.GDP.PCAP.CD  2013
# 2       China         CHN  GDP per capita (current US$)  NY.GDP.PCAP.CD  2014
#
#          Value
# 0  6264.643878
# 1  6991.853866
# 2  7590.016441

# %%
# let's check the 90's in Brazil
Brazil90=pd.read_sql(""" SELECT *
                FROM Indicators
                WHERE IndicatorName ='GDP per capita (current US$)'
                AND CountryName = "Brazil"
                AND Year>=1990;""",
           conn)

Brazil90.head()
# Out:
#   CountryName CountryCode                 IndicatorName   IndicatorCode  Year  \
# 0      Brazil         BRA  GDP per capita (current US$)  NY.GDP.PCAP.CD  1990
# 1      Brazil         BRA  GDP per capita (current US$)  NY.GDP.PCAP.CD  1991
# 2      Brazil         BRA  GDP per capita (current US$)  NY.GDP.PCAP.CD  1992
# 3      Brazil         BRA  GDP per capita (current US$)  NY.GDP.PCAP.CD  1993
# 4      Brazil         BRA  GDP per capita (current US$)  NY.GDP.PCAP.CD  1994
#
#          Value
# 0  3071.627953
# 1  3942.403941
# 2  2578.207009
# 3  2774.174127
# 4  3482.529816

# %%
# let's check other countries in 2014
Countries2014=pd.read_sql(""" SELECT *
                FROM Indicators
                WHERE Year=2014;""",
           conn)

Countries2014
# Out:
#        CountryName CountryCode  \
# 0       Arab World         ARB
# 1       Arab World         ARB
# 2       Arab World         ARB
# 3       Arab World         ARB
# 4       Arab World         ARB
# ...            ...         ...
# 107384    Zimbabwe         ZWE
# 107385    Zimbabwe         ZWE
# 107386    Zimbabwe         ZWE
# 107387    Zimbabwe         ZWE
# 107388    Zimbabwe         ZWE
#
#                                             IndicatorName      IndicatorCode  \
# 0       Adolescent fertility rate (births per 1,000 wo...        SP.ADO.TFRT
# 1       Age dependency ratio (% of working-age populat...        SP.POP.DPND
# 2       Age dependency ratio, old (% of working-age po...     SP.POP.DPND.OL
# 3       Age dependency ratio, young (% of working-age ...     SP.POP.DPND.YG
# 4       Agriculture value added per worker (constant 2...     EA.PRD.AGRI.KD
# ...                                                   ...                ...
# 107384                                   Urban population        SP.URB.TOTL
# 107385                      Urban population (% of total)  SP.URB.TOTL.IN.ZS
# 107386                 Urban population growth (annual %)        SP.URB.GROW
# 107387               Use of IMF credit (DOD, current US$)     DT.DOD.DIMF.CD
# 107388  Women's share of population ages 15+ living wi...  SH.DYN.AIDS.FE.ZS
#
#         Year         Value
# 0       2014  4.822815e+01
# 1       2014  6.179190e+01
# 2       2014  6.825914e+00
# 3       2014  5.332138e+01
# 4       2014  3.353247e+03
# ...      ...           ...
# 107384  2014  4.955055e+06
# 107385  2014  3.250100e+01
# 107386  2014  1.837793e+00
# 107387  2014  4.867300e+08
# 107388  2014  5.920269e+01
#
# [107389 rows x 6 columns]

# %% [markdown]
# # 3- Aggregating and Summarizing

# %%
# let's search for the highest GDP per capita in 2014
HighestGDP=pd.read_sql(""" SELECT CountryName, MAX (Value)
                FROM Indicators
                WHERE IndicatorName ='GDP per capita (current US$)'
                AND Year=2014;""",
           conn)

HighestGDP.head()
# Out:
#   CountryName    MAX (Value)
# 0  Luxembourg  116664.262488

# %%
#Let's order (and reafirm the highest GDP per capita)
#the default is the ascending order in order by
OrderedHighestGDP=pd.read_sql(""" SELECT *
                FROM Indicators
                WHERE IndicatorName ='GDP per capita (current US$)'
                AND Year=2014
                ORDER BY value DESC 
                Limit 5;""",
           conn)

OrderedHighestGDP
# Out:
#         CountryName CountryCode                 IndicatorName   IndicatorCode  \
# 0        Luxembourg         LUX  GDP per capita (current US$)  NY.GDP.PCAP.CD
# 1            Norway         NOR  GDP per capita (current US$)  NY.GDP.PCAP.CD
# 2             Qatar         QAT  GDP per capita (current US$)  NY.GDP.PCAP.CD
# 3  Macao SAR, China         MAC  GDP per capita (current US$)  NY.GDP.PCAP.CD
# 4       Switzerland         CHE  GDP per capita (current US$)  NY.GDP.PCAP.CD
#
#    Year          Value
# 0  2014  116664.262488
# 1  2014   97307.421592
# 2  2014   96732.402545
# 3  2014   96038.050724
# 4  2014   85594.326601

# %%
# Let's compare the averages
OrderedAVGGDP=pd.read_sql(""" SELECT CountryName, AVG (Value)
                FROM Indicators
                WHERE IndicatorName ='GDP per capita (current US$)'
                AND Year=2014;""",
           conn)

OrderedAVGGDP
# Out:
#   CountryName   AVG (Value)
# 0  Arab World  14081.842529

# %%
#how many measures during this time?
numMeasures=pd.read_sql(""" SELECT COUNT (Value)
                FROM Indicators
                WHERE IndicatorName ='GDP per capita (current US$)'
                AND Year=2014;""",
           conn)


numMeasures
# Out:
#    COUNT (Value)
# 0            215

# %%
# important to know that Angola has less measures during this time
numMeasures=pd.read_sql(""" SELECT COUNT (Value)
                FROM Indicators
                WHERE IndicatorName ='GDP per capita (current US$)'
                AND CountryName='Angola'
                AND Year=2014;""",
           conn)


numMeasures
# Out:
#    COUNT (Value)
# 0              0

# %% [markdown]
# # 4- JOINs

# %%
# check the head
country=pd.read_sql("""SELECT *
               FROM Country;""",
           conn)

country.head()
# Out:
#   CountryCode       ShortName       TableName  \
# 0         AFG     Afghanistan     Afghanistan
# 1         ALB         Albania         Albania
# 2         DZA         Algeria         Algeria
# 3         ASM  American Samoa  American Samoa
# 4         ADO         Andorra         Andorra
#
#                                   LongName Alpha2Code    CurrencyUnit  \
# 0             Islamic State of Afghanistan         AF  Afghan afghani
# 1                      Republic of Albania         AL    Albanian lek
# 2  People's Democratic Republic of Algeria         DZ  Algerian dinar
# 3                           American Samoa         AS     U.S. dollar
# 4                  Principality of Andorra         AD            Euro
#
#                                         SpecialNotes  \
# 0  Fiscal year end: March 20; reporting period fo...
# 1
# 2
# 3
# 4
#
#                        Region           IncomeGroup Wb2Code  ...  \
# 0                  South Asia            Low income      AF  ...
# 1       Europe & Central Asia   Upper middle income      AL  ...
# 2  Middle East & North Africa   Upper middle income      DZ  ...
# 3         East Asia & Pacific   Upper middle income      AS  ...
# 4       Europe & Central Asia  High income: nonOECD      AD  ...
#
#        GovernmentAccountingConcept              ImfDataDisseminationStandard  \
# 0  Consolidated central government  General Data Dissemination System (GDDS)
# 1     Budgetary central government  General Data Dissemination System (GDDS)
# 2     Budgetary central government  General Data Dissemination System (GDDS)
# 3
# 4
#
#                               LatestPopulationCensus  \
# 0                                               1979
# 1                                               2011
# 2                                               2008
# 3                                               2010
# 4  2011. Population data compiled from administra...
#
#                                LatestHouseholdSurvey  \
# 0  Multiple Indicator Cluster Survey (MICS), 2010/11
# 1       Demographic and Health Survey (DHS), 2008/09
# 2     Multiple Indicator Cluster Survey (MICS), 2012
# 3
# 4
#
#           SourceOfMostRecentIncomeAndExpenditureData  \
# 0            Integrated household survey (IHS), 2008
# 1  Living Standards Measurement Study Survey (LSM...
# 2            Integrated household survey (IHS), 1995
# 3
# 4
#
#   VitalRegistrationComplete LatestAgriculturalCensus LatestIndustrialData  \
# 0                                            2013/14
# 1                       Yes                     2012                 2011
# 2                                                                    2010
# 3                       Yes                     2007
# 4                       Yes
#
#   LatestTradeData LatestWaterWithdrawalData
# 0            2013                      2000
# 1            2013                      2006
# 2            2013                      2001
# 3
# 4            2006
#
# [5 rows x 31 columns]

# %%
# let's make a join to get the information about indicators GDP related measured in 2014 in Brazil
JoinedBrazilGDP=pd.read_sql(""" SELECT Indicators.CountryName, Indicators.Year, Indicators.Value, Country.Region
                FROM Indicators
                INNER JOIN Country ON Indicators.CountryCode=Country.CountryCode
                WHERE Indicators.CountryName='Brazil'
                AND Indicators.Year=2014;""",
           conn)

JoinedBrazilGDP.head()
# Out:
#   CountryName  Year      Value                     Region
# 0      Brazil  2014  67.310600  Latin America & Caribbean
# 1      Brazil  2014  45.142889  Latin America & Caribbean
# 2      Brazil  2014  10.995047  Latin America & Caribbean
# 3      Brazil  2014  34.147841  Latin America & Caribbean
# 4      Brazil  2014   4.011718  Latin America & Caribbean

# %% [markdown]
# # 5- Using CASE WHEN
#
# CASE statements are like "IF this THEN that".
# Here I'm going to use CASE statements for a custom discretization.

# %%
# I'm using arbitrary values, this is an exercise with didactic purposes: cuts on 10000 and 80000
didactic=pd.read_sql(""" SELECT *,
                   CASE WHEN Value < 10000 THEN 'Low'
                   WHEN Value > 80000 THEN 'High'
                   ELSE 'Medium' END AS DidacticCategory
                   FROM Indicators
                   WHERE IndicatorName='GDP per capita (current US$)'
                   AND Year=2014;""",
              conn)

didactic.head()
# Out:
#                                CountryName CountryCode  \
# 0                               Arab World         ARB
# 1                   Caribbean small states         CSS
# 2           Central Europe and the Baltics         CEB
# 3  East Asia & Pacific (all income levels)         EAS
# 4    East Asia & Pacific (developing only)         EAP
#
#                   IndicatorName   IndicatorCode  Year         Value  \
# 0  GDP per capita (current US$)  NY.GDP.PCAP.CD  2014   7386.428444
# 1  GDP per capita (current US$)  NY.GDP.PCAP.CD  2014  10164.320958
# 2  GDP per capita (current US$)  NY.GDP.PCAP.CD  2014  14086.521810
# 3  GDP per capita (current US$)  NY.GDP.PCAP.CD  2014   9475.349629
# 4  GDP per capita (current US$)  NY.GDP.PCAP.CD  2014   6240.403751
#
#   DidacticCategory
# 0              Low
# 1           Medium
# 2           Medium
# 3              Low
# 4              Low

# %% [markdown]
# # 6 - Window Function
# With a window function, we can make calculations across rows "in a window" and return a value for each row.
# This window can be, for example, grouped sets based on another column or even an ordered set.

# %%
# adding the mean of last 3 years using window function
# these are the years I found answers for them (not exactly the last 3 years)
mean3Y=pd.read_sql(""" SELECT *,
                ROUND(AVG(Value) OVER (PARTITION BY CountryCode),0) AS AVG_3Y
                FROM Indicators
                WHERE IndicatorName='GDP per capita (current US$)'
                AND Year IN (2012,2013,2014);""",
           conn)

mean3Y.head()
# Out:
#    CountryName CountryCode                 IndicatorName   IndicatorCode  \
# 0      Andorra         ADO  GDP per capita (current US$)  NY.GDP.PCAP.CD
# 1      Andorra         ADO  GDP per capita (current US$)  NY.GDP.PCAP.CD
# 2  Afghanistan         AFG  GDP per capita (current US$)  NY.GDP.PCAP.CD
# 3  Afghanistan         AFG  GDP per capita (current US$)  NY.GDP.PCAP.CD
# 4  Afghanistan         AFG  GDP per capita (current US$)  NY.GDP.PCAP.CD
#
#    Year         Value   AVG_3Y
# 0  2012  39666.369215  41236.0
# 1  2013  42806.522553  41236.0
# 2  2012    690.842629    664.0
# 3  2013    666.795051    664.0
# 4  2014    633.569247    664.0

# %% [markdown]
# # 7 - Common Table Expression (CTE)
# A CTE will save results of a query temporary. It can help simplifying some queries and, for example, can also help filtering based on ranking results.

# %%
# the first place from each year
# creates a Common Table Expression (CTE) named place_1
Rank1 = pd.read_sql("""
    WITH place_1 AS (
        SELECT *,
               RANK() OVER (PARTITION BY Year ORDER BY Value DESC) AS Rank
        FROM Indicators
        WHERE IndicatorName = 'GDP per capita (current US$)'
          AND Year IN (2012, 2013, 2014)
    )
    SELECT *
    FROM place_1
    WHERE Rank = 1;
    """, conn)

Rank1
# Out:
#      CountryName CountryCode                 IndicatorName   IndicatorCode  \
# 0  Liechtenstein         LIE  GDP per capita (current US$)  NY.GDP.PCAP.CD
# 1     Luxembourg         LUX  GDP per capita (current US$)  NY.GDP.PCAP.CD
# 2     Luxembourg         LUX  GDP per capita (current US$)  NY.GDP.PCAP.CD
#
#    Year          Value  Rank
# 0  2012  149160.758132     1
# 1  2013  113726.638979     1
# 2  2014  116664.262488     1
